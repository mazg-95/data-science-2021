# %% [markdown]
# # Tarea 4
# ### HackerRank Practice por Marco Zuñiga
# ##### 06/03/2021
# **HackerRank User**: @mazg95
# **Profile URL**: https://www.hackerrank.com/mazg95?hr_r=1

# %% [markdown]
# #### Python IF - ELSE problem
# https://www.hackerrank.com/challenges/py-if-else/problem
#
# ![image.png](attachment:1841c0a5-301f-401d-985d-8f0c741d959c.png)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys



if __name__ == '__main__':
    n = int(input().strip())
    if n % 2 == 0:
        if 2 <= n <= 5:
            print("Not Weird")
        elif 6 <= n <= 20:
            print("Weird")
        else:
            print("Not Weird")
    else:
        print("Weird")

# %% [markdown]
# #### Python Arithmetic Operators
# https://www.hackerrank.com/challenges/python-arithmetic-operators/problem
#
# ![image.png](attachment:0a2e605f-d7a4-489b-8b61-a5a225250521.png)

# %%
if __name__ == '__main__':
    a = int(raw_input())
    b = int(raw_input())
    print a + b
    print a - b
    print a * b

# %% [markdown]
# #### Python division problem
# https://www.hackerrank.com/challenges/python-division/problem
#
# ![image.png](attachment:c5208578-dc1f-406d-95a1-3943d19dc7a7.png)

# %%
from __future__ import division

if __name__ == '__main__':
    a = int(raw_input())
    b = int(raw_input())
    print a // b
    print a / b

# %% [markdown]
# #### Python Loops Problem
# https://www.hackerrank.com/challenges/python-loops/problem
#
# ![image.png](attachment:6039cb86-2283-448f-9ebf-744a46db296a.png)

# %%
if __name__ == '__main__':
    n = int(input())
    print(*[i**2 for i in range(n)], sep='\n')

# %% [markdown]
# #### Write a Function Problem
# https://www.hackerrank.com/challenges/write-a-function/problem
#
# ![image.png](attachment:407d8c8f-9022-4329-8e04-591e8bf78a3c.png)

# %%
def is_leap(year):
    """The year can be evenly divided by 4, is a leap year, unless:
    The year can be evenly divided by 100, it is NOT a leap year, unless:
    The year is also evenly divisible by 400. Then it is a leap year."""
    # Write your logic here
    return year % 4 == 0 and (year % 100 != 0 or year % 400 == 0)

# %% [markdown]
# #### Find Second Maximum Number in a List Problem
# https://www.hackerrank.com/challenges/find-second-maximum-number-in-a-list/problem
#
# ![image.png](attachment:72ab1b0f-7c44-4141-b8ef-5e5b8309bfb7.png)

# %%
if __name__ == '__main__':
    n = int(input())
    arr = map(int, input().split())
    arr = sorted(arr, reverse=True)
    runner_up = winner = arr.pop(0)
    while(runner_up == winner):
        runner_up = arr.pop(0)
    print(runner_up)

# %% [markdown]
# ### Finding the percentage Problem
# https://www.hackerrank.com/challenges/finding-the-percentage/problem
#
# ![image.png](attachment:0aba2338-6b74-4125-885f-e31f91ef5fc1.png)

# %%
def get_percetange(student, student_marks):
    marks = student_marks.get(student)
    if not marks: 
        return
    return sum(marks)/len(marks)
    

if __name__ == '__main__':
    n = int(input())
    student_marks = {}
    for _ in range(n):
        name, *line = input().split()
        scores = list(map(float, line))
        student_marks[name] = scores
    query_name = input()
    res = get_percetange(query_name, student_marks)
    print(f"{res:.2f}")

# %% [markdown]
# #### Python lists problem
# https://www.hackerrank.com/challenges/python-lists/problem
#
# ![image.png](attachment:1b537425-f92e-4378-a4a0-1e30a7428aaa.png)

# %%
def build_commands(l):
    def append(val):
        l.append(val)
    def insert(i, val):
        l.insert(i, val)
    def printList():
        print(l)
    def pop():
        return l.pop()
    def reverse():
        return l.reverse()
    def sort():
        return l.sort()
    def remove(e):
        l.remove(e)
    return {
        "append": append,
        "insert": insert,
        "print": printList,
        "pop": pop,
        "reverse": reverse,
        "sort": sort,
        "remove": remove
    }

if __name__ == '__main__':
    N = int(input())
    l = []
    commands = build_commands(l)
    for i in range(N):
        command = input().split()
        params = len(command) > 1 and list(map(int, command[1:]))
        c = commands.get(command[0])
        if params: 
            c(*params)
        else: 
            c()

# %% [markdown]
# #### Tuples problem
# https://www.hackerrank.com/challenges/python-tuples/problem
#
# ![image.png](attachment:787d7b31-e218-48f6-b144-776ca7d05af8.png)

# %%
if __name__ == '__main__':
    n = int(input())
    integer_list = map(int, input().split())
    t = tuple(integer_list)
    print(hash(t))

# %% [markdown]
# #### DefaultDict Tutorial
# https://www.hackerrank.com/challenges/defaultdict-tutorial/problem
#
# ![image.png](attachment:b29b818d-59a6-4fb5-b131-28dcdf37c294.png)

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT

from collections import defaultdict

n, m = input().split(" ")

a = [input() for _ in range(int(n))]

b = [input() for _ in range(int(m))]

d = defaultdict(lambda: [])


for i, v in enumerate(a, start=1):
    d[v].append(i)

for v in b:
    if not d[v]:
        print(-1)
    else:
        print(*d[v])

# %% [markdown]
# #### Collections Counter Problem
#
# https://www.hackerrank.com/challenges/collections-counter/problem
#
# ![image.png](attachment:065325a6-1c8b-443e-8120-8368a79ab574.png)

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT
from collections import Counter

l = input()
elements = input().split(" ")
inventory = Counter(elements)
earning = 0
for c in range(int(input())):
    ordered_qty, price = input().split(" ")
    qty = inventory[ordered_qty] 
    if(not qty or qty < 0):
        continue
    earning += int(price);
    inventory.subtract([ordered_qty])

print(earning)

# %% [markdown]
# #### Minimum Swaps 2
# https://www.hackerrank.com/challenges/minimum-swaps-2/problem?h_l=interview&playlist_slugs%5B%5D=interview-preparation-kit&playlist_slugs%5B%5D=arrays
#
# ![image.png](attachment:f8e7a3cb-1e98-48c0-b9b7-7e982f5d394c.png)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

# Complete the minimumSwaps function below.
def minimumSwaps(arr):
    i = swaps = 0
    while i < len(arr):
        if arr[i] != i + 1:
            j = arr[i] - 1
            arr[i], arr[j] = arr[j], arr[i]
            swaps += 1
        if arr[i] == i + 1:
            i += 1
    return swaps
        
        
    
if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input())

    arr = list(map(int, input().rstrip().split()))

    res = minimumSwaps(arr)

    fptr.write(str(res) + '\n')

    fptr.close()

# %% [markdown]
# #### Floor, Ceil and Rint
# https://www.hackerrank.com/challenges/floor-ceil-and-rint/problem
#
# ![image.png](attachment:c55e39a6-57cd-4068-bf2c-dda67a0bddf4.png)

# %%
import numpy as np

np.set_printoptions(legacy='1.13')

my_array = np.array(tuple(map(float, input().split())))

print(np.floor(my_array))
print(np.ceil(my_array))
print(np.rint(my_array))

# %% [markdown]
# #### Sorting Bubble Sort
# https://www.hackerrank.com/challenges/ctci-bubble-sort/problem?h_l=interview&playlist_slugs%5B%5D=interview-preparation-kit&playlist_slugs%5B%5D=sorting
#
# ![image.png](attachment:d49fdd0b-5860-4eae-a13d-9691c21fa4c0.png)

# %%
#!/bin/python3

import math
import os
import random
import re
import sys

# Complete the countSwaps function below.
def countSwaps(a):
    i = j = swaps = 0
    while i < len(a):
        j = 0
        while j < len(a) - 1:
            if a[j] > a[j + 1]: 
                a[j], a[j + 1] = a[j + 1], a[j]
                swaps += 1
            j += 1
        i += 1
    print(f"Array is sorted in {swaps} swaps.")
    print(f"First Element: {a[0]}")
    print(f"Last Element: {a[-1]}")
    
if __name__ == '__main__':
    n = int(input())

    a = list(map(int, input().rstrip().split()))

    countSwaps(a)

# %% [markdown]
# #### Arrays
#
# https://www.hackerrank.com/challenges/np-arrays/problem
#
# ![image.png](attachment:b1fc3c88-4fb0-4c2f-a89d-9f556e5d1807.png)

# %%
def arrays(arr):
    return numpy.array(arr[::-1], float)

# %% [markdown]
# #### Zeros and Ones
# https://www.hackerrank.com/challenges/np-zeros-and-ones/problem
#
# ![image.png](attachment:0dd9e203-907c-4dff-bc37-ad45f85b2aea.png)

# %%
import numpy

sh = tuple(map(int, input().split()))

print(numpy.zeros(sh, dtype=int))
print(numpy.ones(sh, dtype=int))
